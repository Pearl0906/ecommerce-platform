# %%
# %sql
CREATE OR REPLACE TABLE ecommerce.bronze.events
AS
SELECT *
FROM read_files(
  '/Volumes/ecommerce/bronze/raw_data/events.csv',
  format => 'csv',
  header => true,
  inferSchema => true
);

# %%
# %sql
CREATE OR REPLACE TABLE ecommerce.bronze.order_items
AS
SELECT *
FROM read_files(
  '/Volumes/ecommerce/bronze/raw_data/order_items.csv',
  format => 'csv',
  header => true,
  inferSchema => true
);

# %%
# %sql
CREATE OR REPLACE TABLE ecommerce.bronze.orders
AS
SELECT *
FROM read_files(
  '/Volumes/ecommerce/bronze/raw_data/orders.csv',
  format => 'csv',
  header => true,
  inferSchema => true
);

# %%
# %sql
CREATE OR REPLACE TABLE ecommerce.bronze.products
AS
SELECT *
FROM read_files(
  '/Volumes/ecommerce/bronze/raw_data/products.csv',
  format => 'csv',
  header => true,
  inferSchema => true
);

# %%
# %sql
CREATE OR REPLACE TABLE ecommerce.bronze.reviews
AS
SELECT *
FROM read_files(
  '/Volumes/ecommerce/bronze/raw_data/reviews.csv',
  format => 'csv',
  header => true,
  inferSchema => true
);

# %%
# %sql
CREATE OR REPLACE TABLE ecommerce.bronze.users
AS
SELECT *
FROM read_files(
  '/Volumes/ecommerce/bronze/raw_data/users.csv',
  format => 'csv',
  header => true,
  inferSchema => true
);
